# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('baseball.csv')
print(df)
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.isnull().any()
# Out:
# W      False
# R      False
# AB     False
# H      False
# 2B     False
# 3B     False
# HR     False
# BB     False
# SO     False
# SB     False
# RA     False
# ER     False
# ERA    False
# CG     False
# SHO    False
# SV     False
# E      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (30, 17)

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
#plotting Heatmap
plt.figure(figsize=[19,10],facecolor='blue')
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.hist(bins=25,figsize=(20,20))
# display histogram
plt.show()

# %%
sns.set()

# %%
sns.countplot('W', data=df)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='W', ylabel='count'>

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['W'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(x='W',y='R',data=df,s=200);

# %%
sns.boxplot(data=df, x="W")
# Out:
# <AxesSubplot:xlabel='W'>

# %%
sns.countplot('R', data=df )
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='R', ylabel='count'>

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['R'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="R")
# Out:
# <AxesSubplot:xlabel='R'>

# %%
sns.countplot('AB', data=df )
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AB', ylabel='count'>

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['AB'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="AB")
# Out:
# <AxesSubplot:xlabel='AB'>

# %%
sns.scatterplot(x='W',y='AB',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['H'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="H")
# Out:
# <AxesSubplot:xlabel='H'>

# %%
sns.scatterplot(x='W',y='H',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['2B'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="2B")
# Out:
# <AxesSubplot:xlabel='2B'>

# %%
sns.scatterplot(x='W',y='2B',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['3B'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="3B")
# Out:
# <AxesSubplot:xlabel='3B'>

# %%
sns.scatterplot(x='W',y='3B',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['HR'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="HR")
# Out:
# <AxesSubplot:xlabel='HR'>

# %%
sns.scatterplot(x='W',y='HR',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['BB'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="BB")
# Out:
# <AxesSubplot:xlabel='BB'>

# %%
sns.scatterplot(x='W',y='BB',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['SO'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="SO")
# Out:
# <AxesSubplot:xlabel='SO'>

# %%
sns.scatterplot(x='W',y='SO',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['SB'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="SB")
# Out:
# <AxesSubplot:xlabel='SB'>

# %%
sns.scatterplot(x='W',y='SB',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['RA'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="RA")
# Out:
# <AxesSubplot:xlabel='RA'>

# %%
sns.scatterplot(x='W',y='RA',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['ER'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="ER")
# Out:
# <AxesSubplot:xlabel='ER'>

# %%
sns.scatterplot(x='W',y='ER',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['CG'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="CG")
# Out:
# <AxesSubplot:xlabel='CG'>

# %%
sns.scatterplot(x='W',y='CG',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['ERA'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="ERA")
# Out:
# <AxesSubplot:xlabel='ERA'>

# %%
sns.scatterplot(x='W',y='ERA',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['SHO'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="SHO")
# Out:
# <AxesSubplot:xlabel='SHO'>

# %%
sns.scatterplot(x='W',y='SHO',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['SV'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="SV")
# Out:
# <AxesSubplot:xlabel='SV'>

# %%
sns.scatterplot(x='W',y='SV',data=df,s=200);

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['E'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data=df, x="E")
# Out:
# <AxesSubplot:xlabel='E'>

# %%
sns.scatterplot(x='W',y='E',data=df,s=200);

# %% [markdown]
# Build Machine Learn Models

# %% [markdown]
# Splitting the Data into Train and Testing and plot the Required Libraries

# %%
X= df.drop('W',axis=1)
y= df['W']

# %%
X.shape , y.shape
# Out:
# ((30, 16), (30,))

# %%
#splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, 
                                                    random_state=1) 
X_train.shape , X_test.shape ,y_train.shape , y_test.shape
# Out:
# ((21, 16), (9, 16), (21,), (9,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score , mean_squared_error

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(X_test)
pred
# Out:
# array([106.83078865,  86.39067868,  90.67800272,  60.50782625,
#         89.07563476,  81.39554557,  93.30121635,  82.71886464,
#         57.55086151])

# %%
y_test
# Out:
# 17    97
# 21    83
# 10    88
# 19    64
# 14    68
# 20    90
# 26    84
# 3     76
# 24    63
# Name: W, dtype: int64

# %%
lr.score(X_test , y_test)
# Out:
# 0.3146174936334357

# %%
rmse =np.sqrt(mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)

# %%
rmse , r2
# Out:
# (9.469694222756313, 0.3146174936334357)

# %%
pred = lr.predict(X_train)
pred
# Out:
# array([ 72.29809779,  65.68774523,  71.17138396,  81.90387598,
#         92.00263825,  85.49766474,  67.26486163,  77.77520887,
#         80.26004686,  79.18414128,  82.22075287,  97.17091658,
#         93.68517079, 100.45806937,  69.1599526 ,  74.98229553,
#         80.41430912,  81.9747246 ,  84.7732555 ,  84.13752185,
#         93.97736659])

# %%
y_train
# Out:
# 22     71
# 23     67
# 4      74
# 2      81
# 25     92
# 6      87
# 18     68
# 13     76
# 7      81
# 27     79
# 1      83
# 16     98
# 0      95
# 15    100
# 29     68
# 28     74
# 9      78
# 8      80
# 12     85
# 11     86
# 5      93
# Name: W, dtype: int64

# %%
lr.score(X_train , y_train)
# Out:
# 0.9802780428217759

# %%
rmse =np.sqrt(mean_squared_error(y_train,pred))
r2 = r2_score(y_train,pred)

# %%
rmse , r2
# Out:
# (1.3540573114550334, 0.9802780428217759)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, y_train )
# Out:
# RandomForestClassifier()

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)

# %%
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  0.0

# %%
# accuracy on test data
X_train_prediction = model.predict(X_train)
test_data_accuracy = accuracy_score(X_train_prediction, y_train)*100

# %%
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  100.0

# %% [markdown]
# # DecisionTreeClassifier

# %%
dt= DecisionTreeClassifier()
dt.fit(X_train, y_train)
predict = dt.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)*100
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  0.0

# %%
dt= DecisionTreeClassifier()
dt.fit(X_test, y_test)
predict = dt.predict(X_train)
test_data_accuracy = accuracy_score(X_train_prediction, y_train)*100
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  100.0

# %% [markdown]
# # Support Vector Classifier(SVC)

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
predict = dt.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, y_test)*100
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  0.0

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_test, y_test)
predict = dt.predict(X_train)
test_data_accuracy = accuracy_score(X_train_prediction, y_train)*100
print('Accuracy : ', test_data_accuracy)
# Out:
# Accuracy :  100.0
